# %%
import functools
import pandas as pd
import numpy as np
import tqdm
import seaborn as sns
import xarray as xr
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import scipy.integrate as scint
import scipy.interpolate as scinterp
xr.set_options(keep_attrs=True)
import cmath
from Functions import *

# %%
WA_10 = np.load("Cluster_GBWA_E=150mj_PXe=10torr_fstart=20cm_bstop=0p5m.npy")
NA_10 = np.load("Cluster_GBNA_E=150mj_PXe=10torr_fstart=20cm_bstop=0p5m.npy")


WA_25=np.load("Cluster_GBWA_E=150mj_PXe=25torr_fstart=20cm_bstop=0p5m.npy")
NA_25 = np.load("Cluster_GBNA_E=150mj_PXe=25torr_fstart=20cm_bstop=0p5m.npy")

WA_100=np.load("Cluster_GBWA_E=150mj_PXe=100torr_fstart=20cm_bstop=0p5m.npy")
NA_100 = np.load("Cluster_GBNA_E=150mj_PXe=100torr_fstart=20cm_bstop=0p5m.npy")

WA_200=np.load("Cluster_GBWA_E=150mj_PXe=200torr_fstart=20cm_bstop=0p5m.npy")
NA_200 = np.load("Cluster_GBNA_E=150mj_PXe=200torr_fstart=20cm_bstop=0p5m.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 6
#       2 NA_10 = np.load("Cluster_GBNA_E=150mj_PXe=10torr_fstart=20cm_bstop=0p5m.npy")
#       5 WA_25=np.load("Cluster_GBWA_E=150mj_PXe=25torr_fstart=20cm_bstop=0p5m.npy")
# ----> 6 NA_25 = np.load("Cluster_GBNA_E=150mj_PXe=25torr_fstart=20cm_bstop=0p5m.npy")
#       8 WA_100=np.load("Cluster_GBWA_E=150mj_PXe=100torr_fstart=20cm_bstop=0p5m.npy")
#       9 NA_100 = np.load("Cluster_GBNA_E=150mj_PXe=100torr_fstart=20cm_bstop=0p5m.npy")
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# ...

# %%
WA_10 = WA_10[:,:,0]
NA_10 = NA_10[:,:,0]

WA_25 = WA_25[:,:,0]
NA_25 = NA_25[:,:,0]

WA_100= WA_100[:,:,0]
NA_100 = NA_100[:,:,0]

WA_200 = WA_200[:,:,0]
NA_200 = NA_200[:,:,0]

# %%
b = np.linspace(f_to_b(0.5e-2,20e-2),f_to_b(0.5e-2,100e-2),10)
dk = np.linspace(2/b[-1],2/b[0],10)
b_, dk_ = np.meshgrid(b, dk)


plt.contourf(b_,dk_,WA_10)
plt.plot(b,2/b,color='r')

plt.show()

plt.contourf(b_,dk_,NA_10)
plt.plot(b,2/b,color='r')

plt.show()

plt.contourf(b_,dk_,WA_25)
plt.plot(b,2/b,color='r')

plt.show()

plt.contourf(b_,dk_,NA_25)
plt.plot(b,2/b,color='r')

plt.show()

plt.contourf(b_,dk_,WA_100)
plt.plot(b,2/b,color='r')

plt.show()

plt.contourf(b_,dk_,NA_100)
plt.plot(b,2/b,color='r')

plt.show()

plt.contourf(b_,dk_,WA_200)
plt.plot(b,2/b,color='r')

plt.show()

plt.contourf(b_,dk_,NA_200)
plt.plot(b,2/b,color='r')

plt.show()

# %%
plt.scatter(dk, WA[:,-1])
