# %%
import functools
import pandas as pd
import numpy as np
import tqdm
import seaborn as sns
import xarray as xr
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import scipy.integrate as scint
import scipy.interpolate as scinterp
xr.set_options(keep_attrs=True)
import cmath
from Functions import *

# %%
WA=np.load("dksamples=10_GBWA_E=150mj_PXe=10torr_fstart=20cm_fstop=100cm.npy")
NA = np.load("dksamples=10_GBWA_E=150mj_PXe=10torr_fstart=20cm_fstop=100cm.npy")

# %%
b = np.linspace(f_to_b(0.5e-2,20e-2),f_to_b(0.5e-2,100e-2),10)
dk = np.linspace(2/b[-1],2/b[0],10)
b_, dk_ = np.meshgrid(b, dk)
plt.contourf(b_,dk_,WA[:,:,0])
plt.plot(b,2/b,color='r')
#plt.savefig(NA_Name)

# %%
PAr_to_dk(0,10)
# Out:
# -1836.0

# %%
PAr_to_dk(2500,10)
# Out:
# 38139.0
